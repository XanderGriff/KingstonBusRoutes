# %%
# import libraries

# graphing libs
import matplotlib.pyplot as plt
from matplotlib import colors
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12.0, 8.0]
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("darkgrid")

# modeling libs
import pandas as pd
import numpy as np
import sys
from scipy import stats, integrate

# %%
# import datafiles

transit_loc = 'oct2017_transit_data.csv'
df = pd.read_csv(transit_loc)

# %%
# print a preview of the first 5 entries in the dataset

df.head(5)
# Out:
#               Date             Time   Class               Operation  Bus  \
# 0  2017-10-01 0:00  1900-01-01 1:43  QUEENS              Exact Fare  620
# 1  2017-10-01 0:00  1900-01-01 1:43  QUEENS              Exact Fare  620
# 2  2017-10-01 0:00  1900-01-01 1:58   ADULT  Pass (Multi-ride card)  620
# 3  2017-10-01 0:00  1900-01-01 1:58  QUEENS              Exact Fare  620
# 4  2017-10-01 0:00  1900-01-01 1:58  QUEENS              Exact Fare  620
#
#    Route   Latitude  Longitude
# 0     17  44.227860 -76.496938
# 1     17  44.227860 -76.496938
# 2     17  44.232035 -76.491397
# 3     17  44.232035 -76.491397
# 4     17  44.232035 -76.491397

# %%
# print a preview of the last 5 entries in the dataset

df.tail(5)
# Out:
#                    Date              Time        Class  \
# 704534  2017-10-01 0:00  1900-01-01 17:07       QUEENS
# 704535  2017-10-01 0:00  1900-01-01 17:07       QUEENS
# 704536  2017-10-01 0:00  1900-01-01 17:07  ST LAWRENCE
# 704537  2017-10-01 0:00  1900-01-01 17:08       QUEENS
# 704538  2017-10-01 0:00  1900-01-01 17:09        ADULT
#
#                       Operation   Bus  Route   Latitude  Longitude
# 704534               Exact Fare  1362    701  44.255135 -76.572517
# 704535               Exact Fare  1362    701  44.255135 -76.572517
# 704536               Exact Fare  1362    701  44.255135 -76.572517
# 704537               Exact Fare  1257     18  44.231425 -76.484333
# 704538  Rides (Multi-ride card)  1046      1  44.224327 -76.494960

# %%
# print basic statistics about the dataset

df.describe()
# Out:
#                  Bus          Route       Latitude      Longitude
# count  704539.000000  704539.000000  704539.000000  704539.000000
# mean     1241.137280     239.365809      40.941516     -70.604451
# std       317.249714     288.489481      13.694826      21.473093
# min       315.000000       1.000000       0.000000    -255.426092
# 25%      1047.000000       3.000000      44.224635     -76.526580
# 50%      1361.000000      15.000000      44.232833     -76.502100
# 75%      1480.000000     502.000000      44.248020     -76.486999
# max      1689.000000     701.000000     255.426092       0.000000

# %%
# get info on attribute type

df.dtypes
# Out:
# Date          object
# Time          object
# Class         object
# Operation     object
# Bus            int64
# Route          int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
# get info on dataset size

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704539 entries, 0 to 704538
# Data columns (total 8 columns):
# Date         704539 non-null object
# Time         704539 non-null object
# Class        704539 non-null object
# Operation    704539 non-null object
# Bus          704539 non-null int64
# Route        704539 non-null int64
# Latitude     704539 non-null float64
# Longitude    704539 non-null float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 43.0+ MB

# %%
# get info on unique values of and number of unique values for nominal columns

unique_cols = ['Class', 'Bus', 'Operation', 'Route']
for col in unique_cols:
    print("COLUMN: " + col)
    print("COUNT: " + str(len(df[col].unique())))
    print("VALUES:")
    print(df[col].unique())
    print('\n')
# Out:
# COLUMN: Class
# COUNT: 11
# VALUES:
# ['QUEENS' 'ADULT' 'Youth' 'ST LAWRENCE' 'Child' 'Transpass' 'SENIOR'
#  'Student' 'YOUTH' 'Commuter' 'CHILD']
#
#
# COLUMN: Bus
# COUNT: 64
# VALUES:
# [ 620 1687 1362 1372 1364 1479  622 1684 1368 1046 1683 1689 1365  623 1367
#   729 1482  835  942 1049  944 1359  728 1050  624 1257 1475 1481  834 1369
#  1047  943 1048 1686 1502 1258  836 1480 1506 1254 1476  832 1510 1688 1361
#  1256 1255 1509 1370  833 1477 1366 1504 1685 1363 1051 1474 1360  315 1478
#  1373 1253  945  519]
#
#
# COLUMN: Operation
# COUNT: 6
# VALUES:
# ['Exact Fare' 'Pass (Multi-ride card)' 'Rides (Multi-ride card)'
#  'Transfer - Rides (Multi-ride card)' 'Transfer - Pass (Multi-ride card)'
#  'Transfer - Printed Ticket ']
#
#
# COLUMN: Route
# COUNT: 21
# VALUES:
# [ 17   7 701  15 501 502   1 601   4   3  11   2  12  16  10  18  13   6
#   14  20   8]

# %%
# Reformat duplicate bins in the Class column (Youth, Child)

df.Class.replace(to_replace=dict(YOUTH='Youth', CHILD='Child'), inplace=True)

# %%
# Create columns for hour and minute of the trip

def to_minute(row):
    minute = row['Time'][-2:].strip()
    return minute

def to_hour(row):
    hour = row['Time'][-5:-3].strip()
    return hour
'''
# Use the height and width to calculate the area
def calculate_area(row):
    return row['height'] * row['width']

rectangles_df['area'] = rectangles_df.apply(calculate_area, axis=1)
'''

df['Minute'] = df.apply(to_minute, axis=1)
df['Hour'] = df.apply(to_hour, axis=1)
df.head()
# Out:
#               Date             Time   Class               Operation  Bus  \
# 0  2017-10-01 0:00  1900-01-01 1:43  QUEENS              Exact Fare  620
# 1  2017-10-01 0:00  1900-01-01 1:43  QUEENS              Exact Fare  620
# 2  2017-10-01 0:00  1900-01-01 1:58   ADULT  Pass (Multi-ride card)  620
# 3  2017-10-01 0:00  1900-01-01 1:58  QUEENS              Exact Fare  620
# 4  2017-10-01 0:00  1900-01-01 1:58  QUEENS              Exact Fare  620
#
#    Route   Latitude  Longitude Minute Hour
# 0     17  44.227860 -76.496938     43    1
# 1     17  44.227860 -76.496938     43    1
# 2     17  44.232035 -76.491397     58    1
# 3     17  44.232035 -76.491397     58    1
# 4     17  44.232035 -76.491397     58    1

# %%
# reformate date to remove unnecessary information

def format_date(row):
    date = int(row['Date'][8:10])
    return date

df['Date'] = df.apply(format_date, axis=1)
df.head(5)
# Out:
#    Date             Time   Class               Operation  Bus  Route  \
# 0     1  1900-01-01 1:43  QUEENS              Exact Fare  620     17
# 1     1  1900-01-01 1:43  QUEENS              Exact Fare  620     17
# 2     1  1900-01-01 1:58   ADULT  Pass (Multi-ride card)  620     17
# 3     1  1900-01-01 1:58  QUEENS              Exact Fare  620     17
# 4     1  1900-01-01 1:58  QUEENS              Exact Fare  620     17
#
#     Latitude  Longitude Minute Hour
# 0  44.227860 -76.496938     43    1
# 1  44.227860 -76.496938     43    1
# 2  44.232035 -76.491397     58    1
# 3  44.232035 -76.491397     58    1
# 4  44.232035 -76.491397     58    1

# %%
# add day column to dataset

days = {0: "Saturday", 1: "Sunday", 2: "Monday", 3: "Tuesday", 4: "Wednesday", 5: "Thursday", 6: "Friday"}
def add_day(row):
    day_index = row['Date'] % 7
    day = days[day_index]
    return day

df['Weekday'] = df.apply(add_day, axis=1)
df.head(10)
# Out:
#    Date             Time   Class               Operation   Bus  Route  \
# 0     1  1900-01-01 1:43  QUEENS              Exact Fare   620     17
# 1     1  1900-01-01 1:43  QUEENS              Exact Fare   620     17
# 2     1  1900-01-01 1:58   ADULT  Pass (Multi-ride card)   620     17
# 3     1  1900-01-01 1:58  QUEENS              Exact Fare   620     17
# 4     1  1900-01-01 1:58  QUEENS              Exact Fare   620     17
# 5     1  1900-01-01 1:58  QUEENS              Exact Fare   620     17
# 6     1  1900-01-01 5:47  QUEENS              Exact Fare  1687      7
# 7     1  1900-01-01 0:11  QUEENS              Exact Fare   620     17
# 8     1  1900-01-01 0:13  QUEENS              Exact Fare   620     17
# 9     1  1900-01-01 0:15  QUEENS              Exact Fare   620     17
#
#     Latitude  Longitude Minute Hour Weekday
# 0  44.227860 -76.496938     43    1  Sunday
# 1  44.227860 -76.496938     43    1  Sunday
# 2  44.232035 -76.491397     58    1  Sunday
# 3  44.232035 -76.491397     58    1  Sunday
# 4  44.232035 -76.491397     58    1  Sunday
# 5  44.232035 -76.491397     58    1  Sunday
# 6  44.261297 -76.507313     47    5  Sunday
# 7  44.227837 -76.497027     11    0  Sunday
# 8  44.227317 -76.500192     13    0  Sunday
# 9  44.223395 -76.513757     15    0  Sunday

# %%
# plot occurance frequency of passenger class

ax = sns.countplot(x="Class", data=df);

# %%
# plot occurance frequency of travel days

ax = sns.countplot(x="Weekday", data=df);
